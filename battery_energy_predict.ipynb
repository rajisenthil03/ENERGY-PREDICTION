# %%
import pandas as pd

# Load the preprocessed dataset
data = pd.read_csv('preprocessed_dataset.csv')

# Show basic info
print("Shape of dataset:", data.shape)
print("\nMissing values in each column:\n", data.isnull().sum())

# Example: normalize numeric columns (if needed)
numeric_cols = data.select_dtypes(include=['float64', 'int64']).columns
data[numeric_cols] = (data[numeric_cols] - data[numeric_cols].min()) / (data[numeric_cols].max() - data[numeric_cols].min())

# Display first few rows
data.head()

# Save the final cleaned dataset
data.to_csv('final_preprocessed_battery_data.csv', index=False)
print("\n✅ Final preprocessed dataset saved as 'final_preprocessed_battery_data.csv'")
# Out:
# Shape of dataset: (490, 6)
#
# Missing values in each column:
#  Voltage_measured        0
# Current_measured        0
# Temperature_measured    0
# Current_load            0
# Voltage_load            0
# Time                    0
# dtype: int64
#
# ✅ Final preprocessed dataset saved as 'final_preprocessed_battery_data.csv'

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 6))
plt.plot(data['Time'], data['Temperature_measured']) # Changed to Temperature_measured
plt.xlabel('Time')
plt.ylabel('Temperature Measured') # Changed ylabel
plt.title('Temperature Measured vs. Time') # Changed title
plt.grid(True)
plt.show()
